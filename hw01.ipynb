# %% [markdown]
# hw01

# %%
from random import randint

# %%
class Ferma:
    def __init__ (self, livspace=None, pole=None, ogorod=None, zagon=None, kuryatnik=None, paseka=None):
        self.livspace = livspace
        self.pole = pole
        self.ogorod = ogorod
        self.zagon = zagon 
        self.kuryatnik = kuryatnik
        self.paseka = paseka

    def ferma(self):
        ochki = 10

        print('Вам предстоит выбрать характеристики вашей фермы. Будьте внимательны при настройках.')
        print('Всего 10 очков для обустройства фермы. Чем больше очков вы потратите на дом, огород или курятник, тем меньше у вас останется места для загона или картофельного поля.\nСоответсвенно, получится меньше вырастить коров или картофеля')
        print('Настройки фермы:\nЖилплощадь - обязательна\nКартофельное поле - необязательно\nОгород - обязательно\nЗагон - обязательно\nКурятник - необязательно\nПасека - необязательно.')
        print('Пожалуйста, придерживайтесь рамок лимита строительства. Автор игры хлебушек, который мог забыть прописать код ошибки, и игра в конечном итоге сломается. Спасибо!\n\n')
        
        print("Настройка жилплощади (обязательное значение)")
        livspace = int(input('Выберите жилплощадь: '))
        if livspace <= 0:
            print('Вы ввели неверное значение для жилплощади. Пожалуйста, введите чисто от 1 до 10.')
            livspace = int(input('Выберите жилплощадь: '))
        
        ochki -= livspace
        print(f'Ваша жилплощать: {livspace}')
        self.livspace = livspace
        print(f'Очки для строительства, которые у вас остались: {ochki}')


        if ochki > 0:
            print("Настройка картофельного поля (необязательное значение)")
            pole = int(input('Выберите размер картофельного поля: '))
            if pole < 0:
                print(f'Вы ввели неверное значение для картофельного поля. Пожалуйста, введите чисто от 0 до {ochki}.')
                pole = int(input('Выберите размер картофельного поля: '))
            if (ochki - pole) < 0:
                print(f'Вы превысили лимит строительства. Пожалуйста, введите чисто от 0 до {ochki}.')
                pole = int(input('Выберите размер картофельного поля: '))

            ochki -= pole
            print(f'Ваше картофельное поле: {pole}')
            self.pole = pole
            print(f'Очки для строительства, которые у вас остались: {ochki}')
            
        else:
            print('Вернитесь в начало настроек и попроуйте создать ферму заново!')
            Ferma.ferma(self)

        if ochki > 0:
            print("Настройка огорода (обязательное значение)")
            ogorod = int(input('Выберите размер огорода: '))
            if ogorod <= 0:
                print(f'Вы ввели неверное значение для огорода. Пожалуйста, введите чисто от 1 до {ochki}.')
                ogorod = int(input('Выберите размер огорода: '))
            if (ochki - ogorod) < 0:
                print(f'Вы превысили лимит строительства. Пожалуйста, введите чисто от 1 до {ochki}.')
                ogorod = int(input('Выберите размер огорода: '))
            
            ochki -= ogorod
            print(f'Ваш огород: {ogorod}')
            self.ogorod = ogorod
            print(f'Очки для строительства, которые у вас остались: {ochki}')
        
        else:
            print('Вернитесь в начало настроек и попроуйте создать ферму заново!')
            Ferma.ferma(self)

        if ochki > 0:
            print("Настройка загона для скота (обязательное значение)")
            zagon = int(input('Выберите размер загона: '))
            if zagon <= 0:
                print(f'Вы ввели неверное значение для загона. Пожалуйста, введите чисто от 1 до {ochki}.')
                zagon = int(input('Выберите размер : '))
            if (ochki - zagon) < 0:
                print(f'Вы превысили лимит строительства. Пожалуйста, введите чисто от 1 до {ochki}.')
                zagon = int(input('Выберите размер огорода: '))
            
            ochki -= zagon
            print(f'Ваш загон для скота: {zagon}')
            self.zagon = zagon
            print(f'Очки для строительства, которые у вас остались: {ochki}')
        
        else:
            print('Вернитесь в начало настроек и попроуйте создать ферму заново!')
            Ferma.ferma(self)

        if ochki > 0:
            print("Настройка курятника (необязательное значение)")
            kuryatnik = int(input('Выберите размер курятника: '))
            if kuryatnik < 0:
                print(f'Вы ввели неверное значение для курятника. Пожалуйста, введите чисто от 0 до {ochki}.')
                kuryatnik = int(input('Выберите размер курятника: '))
            if (ochki - kuryatnik) < 0:
                print(f'Вы превысили лимит строительства. Пожалуйста, введите чисто от 1 до {ochki}.')
                kuryatnik = int(input('Выберите размер курятника: '))
            
            ochki -= kuryatnik
            print(f'Ваш курятник: {kuryatnik}')
            self.kuryatnik = kuryatnik
            print(f'Очки для строительства, которые у вас остались: {ochki}')
        
        else:
            print('Вернитесь в начало настроек и попроуйте создать ферму заново!')
            Ferma.ferma(self)    


        if ochki > 0:
            print("Настройка пасеки (необязательное значение)")
            paseka = int(input('Выберите размер пасеки: '))
            if paseka < 0:
                print(f'Вы ввели неверное значение для пасеки. Пожалуйста, введите чисто от 0 до {ochki}.')
                paseka = int(input('Выберите размер пасеки: '))
            if (ochki - paseka) < 0:
                print(f'Вы превысили лимит строительства. Пожалуйста, введите чисто от 0 до {ochki}.')
                paseka = int(input('Выберите размер пасеки: '))

            ochki -= paseka
            print(f'Вашей пасеки: {paseka}')
            self.paseka = paseka
            print(f'Очки для строительства, которые у вас остались: {ochki}')
            
        else:
            print('Вернитесь в начало настроек и попроуйте создать ферму заново!')
            Ferma.ferma(self)

class Fermer:
    def __init__ (self, name=None, start_money=None, skrytiy_stat_1=None, skrytiy_stat_2=None):
        self.name = name
        self.start_money = start_money
        self.kharakter = skrytiy_stat_1
        self.um = skrytiy_stat_2
        self.zapasy_myasa = {'Свинина' : 0, 'Говядина' : 0, 'Курятина' : 0, 'Индейка' : 0, 'Молоко' : 0, 'Яйца' : 0, 'Мёд' : 0}
        self.zapasy_ovoschey = {'Огурцы' : 0, 'Картофель' : 0, 'Помидоры' : 0, 'Перец' : 0, 'Кабачки' : 0}
        self.ferma = Ferma.ferma(self)

    def char(self):
        name = input(('Выберите имя персонажа: \n'))
        self.name = name
        rezhim = int(input('Выберите режим игры!\nЛёгкий режим - 1.\nСложный режим - 2'))
        if rezhim == 1:
            self.start_money = 50000
        elif rezhim == 2:
            self.start_money = 15000
        print(f'Добро пожаловать, {self.name}!')

    def skrytiy_stat_1(self):
        print('Пройдите небольшой тест, чтобы определить скрытый стат вашего фермера!\n')
        print('В тесте будет 6 вопросов. Отвечайте честно!\n')
        
        print('Вопрос 1.\n')
        vop_1 = int(input(f'Если я вижу сильно расстроенного или плачущего человека, мне тоже становится больно. Да - 1, нет - 2.')) 
        print('Вопрос 2.\n')
        vop_2 = int(input(f'Я часто чувствую, что у близкого мне человека что-то не так, даже на расстоянии. Да - 1, нет - 2.')) 
        print('Вопрос 3.\n')
        vop_3 = int(input(f'Я испытываю сильные эмоции при просмотре фильма или чтении художественной книги и часто переживаю за героев. Да - 1, нет - 2.')) 
        print('Вопрос 4.\n')
        vop_4 = int(input(f'Чужой смех заразителен. Да - 1, нет - 2.')) 
        print('Вопрос 5.\n')
        vop_5 = int(input(f'Я считаю, что плакать от счастья - глупо. Да - 1, нет - 2.')) 
        print('Вопрос 6.\n')
        vop_6 = int(input(f'Я часто чувствую себя неловко, если друг рассказывает мне о своих проблемах. Да - 1, нет - 2.')) 

        if vop_5 == 1:
            vop_5 = 2
        else:
            vop_5 = 1

        if vop_6 == 1:
            vop_6 = 2
        else:
            vop_6 = 1

        otvety = [vop_1, vop_2, vop_3, vop_4, vop_5, vop_6]

        if sum(otvety) > 6:
            print('Спасибо! Скрытый стат вашего персонажа определен!')
            self.kharakter = 'zlyuka'
        else:
            print('Спасибо! Скрытый стат вашего персонажа определен!')
            self.kharakter = 'empat'

    def skrytiy_stat_2(self):
        print('Пройдите небольшой тест, чтобы определить скрытый стат вашего фермера!\n')
        print('В тесте будет 6 вопросов. Отвечайте честно!\n')

        print('Вопрос 1.\n') 
        vop_1 = int(input(f'Сколько будет 2 + 2 * 2 ^ 2? 10 - 1, 16 - 2.')) 
        print('Вопрос 2.\n') 
        vop_2 = int(input(f'Где находится Суринам? В Африке - 1, в Америке - 2.')) 
        print('Вопрос 3.\n') 
        vop_3 = int(input(f'Что такое NaCl? Морская соль - 1, Поваренная соль - 2.')) 
        print('Вопрос 4.\n') 
        vop_4 = int(input(f'Что находится в крови у человека? Лейкоциты - 1, хлорофилл - 2.')) 
        print('Вопрос 5.\n') 
        vop_5 = int(input(f'Когда крестили Русь? В 1988 году - 1, в 988 году - 2.')) 
        print('Вопрос 6.\n') 
        vop_6 = int(input(f'Кто убил Кеннеди? Ли Харви Вайнштейн - 1, Ли Харви Освальд - 2.')) 
        
        if vop_1 == 1:
            vop_1 = 2
        else: 
            vop_1 = 1

        if vop_4 == 1:
            vop_4 = 2
        else: 
            vop_4 = 1

        otvety = [vop_1, vop_2, vop_3, vop_4, vop_5, vop_6]

        if sum(otvety) > 6:
            print('Спасибо! Скрытый стат вашего персонажа определен!')
            self.um = 'um'
        else:
            print('Спасибо! Скрытый стат вашего персонажа определен!')
            self.um = 'neum'

    def kartofel(self):
        kartoshka = input('Хотите ли вы купить и посадить картофель? Да / Нет')
        
        if kartoshka == 'Да' or kartoshka == 'да':
            if self.pole <= 0:
                print('У вас нет картофельного поля!')

            else:    
                kg_kartoshki = int(input(f'Картофель стоит 150 ₽ за 1 кг. У вас {self.start_money} денег.\nРазмер вашего картофельного поля: {self.pole}, поэтому вы можете купить только {self.pole} кг картофеля.\n Сколько картофеля вы хотите приобрести? Введите целое число или 0 для возврата.'))
                
                if kg_kartoshki == 0:
                    print('Вы не купили картошечки и не сможете ее себе пожарить! Но ваш баланс не изменился')
                    print(f'Ваш баланс: {self.start_money}')
                    
                else:
                    if kg_kartoshki > self.pole:
                        print('Вы не можете купить столько картофеля! Вернитесь в начало и попробуйте заново!')
                        Fermer.kartofel(self)
                    else:
                        self.start_money -= kg_kartoshki * 150 
                        print(f'У вас осталось {self.start_money} денег.')
                    
                        pogoda = randint (0, 1)
                        if pogoda == 0:
                            print('У вас ничего не выросло! Вы остались без жареной картошечки и без денег')
                        else:
                            print('У вас выросла картошка! Запасы овощей пополнены!')
                            self.pole -= 1
                            self.zapasy_ovoschey["Картофель"] += kg_kartoshki * 5
                            print(f'Запасы овощей: {self.zapasy_ovoschey}')

        elif kartoshka == "Нет" or kartoshka == "нет":
                print('Вы не купили картошечки и не сможете ее себе пожарить! Но ваш баланс не изменился')
                print(f'Ваш баланс: {self.start_money}')
                

    def gryadki(self):
        ogorod = input('Хотите ли вы купить семена и посадить овощи? Да / Нет')
        if ogorod == "Нет" or ogorod == "нет":
                print('Вы решили не сажать овощи! Но ваш баланс не изменился')
                print(f'Ваш баланс: {self.start_money}')
                

        elif ogorod == 'Да' or ogorod == 'да':
            
            vybor = int(input(f'У вас {self.start_money} денег. Размер вашего огорода: {self.ogorod}, поэтому вы можете купить только {self.ogorod} видов овощей.\nЧто вы хотите приобрести?\nОгурец - 1\nПомидор - 2\nПерец - 3\nКабачок - 4\nВведите целое число или 0 для возврата.'))
            

            if vybor == 0:
                print('Вы решили не сажать овощи! Но ваш баланс не изменился')
                print(f'Ваш баланс: {self.start_money}')
                
            
            elif vybor == 1:
                if self.ogorod <= 0:
                    print('Место на грядках закончилось!')
                else:
                    ogurtsi = int(input(f'Вы решили купить семена огурцов! У вас {self.start_money} денег.\nДоступные семена:\nПартнёр (150₽ за пачку семян) - 1\nSemena Aliexpress (10₽ за пачку семян) - 2. Что вы хотите приобрести? Введите целое число или 0 для возврата.'))
                    if ogurtsi == 0:
                        print('Вы не купили семена огурцов и не сможете закатать баночку на зиму! Но ваш баланс не изменился')
                        print(f'Ваш баланс: {self.start_money}')
                        Fermer.gryadki(self)

                    elif ogurtsi == 1:
                        self.ogorod -= 1
                        ogurtsi_kupit = int(input(f'Сколько пачек семян вы хотите приобрести? Введите целое число или 0 для возврата.'))
                        if ogurtsi_kupit == 0:
                            print('Вы не купили семена огурцов и не сможете закатать баночку на зиму! Но ваш баланс не изменился.')
                            print(f'Ваш баланс: {self.start_money}')
                            Fermer.gryadki(self)
                        else:
                            self.start_money -= ogurtsi_kupit * 150 
                            print(f'У вас осталось {self.start_money} денег.')
                            pogoda = randint (0, 1)
                            if pogoda == 0:
                                print('Погода была плохой, но вы потратились на семена премиум-качества, и это почти не сказалось на урожае! Запасы овощей пополнены!')
                                self.zapasy_ovoschey["Огурцы"] += ogurtsi_kupit * 7
                                print(f'Запасы овощей: {self.zapasy_ovoschey}')
                                Fermer.gryadki(self)
                            else:
                                print('Погода была хорошей! Запасы овощей пополнены!')
                                self.zapasy_ovoschey["Огурцы"] += ogurtsi_kupit * 10
                                print(f'Запасы овощей: {self.zapasy_ovoschey}')
                                Fermer.gryadki(self)

                    else:
                        ogurtsi_kupit = int(input(f'Сколько пачек семян вы хотите приобрести? Введите целое число или 0 для возврата.'))
                        if ogurtsi_kupit == 0:
                            print('Вы не купили семена огурцов и не сможете закатать баночку на зиму! Но ваш баланс не изменился')
                            print(f'Ваш баланс: {self.start_money}')
                            Fermer.gryadki(self)
                        else:
                            self.start_money -= ogurtsi_kupit * 10
                            print(f'У вас осталось {self.start_money} денег.')
                            pogoda = randint (0, 1)

                            if pogoda == 0:
                                print('Погода была плохой, и ваши огурцы сгнили...')
                                Fermer.gryadki(self)
                            else:
                                self.ogorod -= 1
                                print('Погода была хорошей! Но семена дешевые, и урожайность маленькая. Но запасы овощей пополнены!')
                                self.zapasy_ovoschey["Огурцы"] += ogurtsi_kupit * 2
                                print(f'Запасы овощей: {self.zapasy_ovoschey}')
                                Fermer.gryadki(self) 

        
            elif vybor == 2:
                if self.ogorod <= 0:
                    print('Место на грядках закончилось!')
                else:
                    pomidorki = int(input(f'Вы решили купить семена помидоров! У вас {self.start_money} денег.\nДоступные семена:\nПартнёр (150₽ за пачку семян) - 1\nSemena Aliexpress (10₽ за пачку семян) - 2. Что вы хотите приобрести? Введите целое число или 0 для возврата.'))
                    if pomidorki == 0:
                        print('Вы не купили семена помидоров и не сможете закатать баночку на зиму! Но ваш баланс не изменился')
                        print(f'Ваш баланс: {self.start_money}')
                        Fermer.gryadki(self)

                    elif pomidorki == 1:
                        self.ogorod -= 1
                        pomidorki_kupit = int(input(f'Сколько пачек семян вы хотите приобрести? Введите целое число или 0 для возврата.'))
                        if pomidorki_kupit == 0:
                            print('Вы не купили семена помидоров и не сможете закатать баночку на зиму! Но ваш баланс не изменился.')
                            print(f'Ваш баланс: {self.start_money}')
                            Fermer.gryadki(self)
                        else:
                            self.start_money -= pomidorki_kupit * 150 
                            print(f'У вас осталось {self.start_money} денег.')
                            pogoda = randint (0, 1)
                            if pogoda == 0:
                                print('Погода была плохой, но вы потратились на семена премиум-качества, и это почти не сказалось на урожае! Запасы овощей пополнены!')
                                self.zapasy_ovoschey["Помидоры"] += pomidorki_kupit * 7
                                print(f'Запасы овощей: {self.zapasy_ovoschey}')
                                Fermer.gryadki(self)
                            else:
                                print('Погода была хорошей! Запасы овощей пополнены!')
                                self.zapasy_ovoschey["Помидоры"] += pomidorki_kupit * 10
                                print(f'Запасы овощей: {self.zapasy_ovoschey}')
                                Fermer.gryadki(self)

                    else:
                        pomidorki_kupit = int(input(f'Сколько пачек семян вы хотите приобрести? Введите целое число или 0 для возврата.'))
                        if pomidorki_kupit == 0:
                            print('Вы не купили семена помидоров и не сможете закатать баночку на зиму! Но ваш баланс не изменился')
                            print(f'Ваш баланс: {self.start_money}')
                            Fermer.gryadki(self)
                        else:
                            self.start_money -= pomidorki_kupit * 10
                            print(f'У вас осталось {self.start_money} денег.')
                            pogoda = randint (0, 1)

                            if pogoda == 0:
                                print('Погода была плохой, и ваши помидоры сгнили...')
                                Fermer.gryadki(self)
                            else:
                                print('Погода была хорошей! Но семена дешевые, и урожайность маленькая. Но запасы овощей пополнены!')
                                self.ogorod -= 1
                                self.zapasy_ovoschey["Помидоры"] += pomidorki_kupit * 2
                                print(f'Запасы овощей: {self.zapasy_ovoschey}')
                                Fermer.gryadki(self)


            elif vybor == 3:
                if self.ogorod <= 0:
                    print('Место на грядках закончилось!')
                else:
                    pertsy = int(input(f'Вы решили купить семена перца! У вас {self.start_money} денег.\nДоступные семена:\nПартнёр (300₽ за пачку семян) - 1\nSemena Aliexpress (50₽ за пачку семян) - 2. Что вы хотите приобрести? Введите целое число или 0 для возврата.'))
                    if pertsy == 0:
                        print('Вы не купили семена перца и не сможете съесть фаршированное блюдо! Но ваш баланс не изменился')
                        print(f'Ваш баланс: {self.start_money}')
                        Fermer.gryadki(self)

                    elif pertsy == 1:
                        self.ogorod -= 1
                        pertsy_kupit = int(input(f'Сколько пачек семян вы хотите приобрести? Введите целое число или 0 для возврата.'))
                        if pertsy_kupit == 0:
                            print('Вы не купили семена перца и не сможете съесть фаршированное блюдо! Но ваш баланс не изменился.')
                            print(f'Ваш баланс: {self.start_money}')
                            Fermer.gryadki(self)
                        else:
                            self.start_money -= pertsy_kupit * 300
                            print(f'У вас осталось {self.start_money} денег.')
                            pogoda = randint (0, 1)
                            if pogoda == 0:
                                print('Погода была плохой, но вы потратились на семена премиум-качества, и это почти не сказалось на урожае! Запасы овощей пополнены!')
                                self.zapasy_ovoschey["Перец"] += pertsy_kupit * 3
                                print(f'Запасы овощей: {self.zapasy_ovoschey}')
                                Fermer.gryadki(self)
                            else:
                                print('Погода была хорошей! Запасы овощей пополнены!')
                                self.zapasy_ovoschey["Перец"] += pertsy_kupit * 7
                                print(f'Запасы овощей: {self.zapasy_ovoschey}')
                                Fermer.gryadki(self)

                    else:
                        pertsy_kupit = int(input(f'Сколько пачек семян вы хотите приобрести? Введите целое число или 0 для возврата.'))
                        if pertsy_kupit == 0:
                            print('Вы не купили семена перца и не сможете съесть фаршированное блюдо! Но ваш баланс не изменился')
                            print(f'Ваш баланс: {self.start_money}')
                            Fermer.gryadki(self)
                        else:
                            self.start_money -= pertsy_kupit * 50
                            print(f'У вас осталось {self.start_money} денег.')
                            pogoda = randint (0, 1)

                            if pogoda == 0:
                                print('Погода была плохой, и ваши перцы сгнили...')
                                Fermer.gryadki(self)
                            else:
                                print('Погода была хорошей! Но семена дешевые, и урожайность маленькая. Но запасы овощей пополнены!')
                                self.ogorod -= 1
                                self.zapasy_ovoschey["Перец"] += pertsy_kupit * 1
                                print(f'Запасы овощей: {self.zapasy_ovoschey}')
                                Fermer.gryadki(self)



            elif vybor == 4:
                if self.ogorod <= 0:
                    print('Место на грядках закончилось!')
                else:
                    kabachki = int(input(f'Вы решили купить семена кабачков! У вас {self.start_money} денег.\nДоступные семена:\nПартнёр (500₽ за пачку семян) - 1\nSemena Aliexpress (100₽ за пачку семян) - 2. Что вы хотите приобрести? Введите целое число или 0 для возврата.'))
                    if kabachki == 0:
                        print('Вы не купили семена кабачка и не сможете пожарить себе кабачки! Но ваш баланс не изменился')
                        print(f'Ваш баланс: {self.start_money}')
                        Fermer.gryadki(self)

                    elif kabachki == 1:
                        self.ogorod -= 1
                        kabachki_kupit = int(input(f'Сколько пачек семян вы хотите приобрести? Введите целое число или 0 для возврата.'))
                        if kabachki_kupit == 0:
                            print('Вы не купили семена кабачка и не сможете пожарить себе кабачки! Но ваш баланс не изменился.')
                            print(f'Ваш баланс: {self.start_money}')
                            Fermer.gryadki(self)
                        else:
                            self.start_money -= kabachki_kupit * 500
                            print(f'У вас осталось {self.start_money} денег.')
                            pogoda = randint (0, 1)
                            if pogoda == 0:
                                print('Погода была плохой, но вы потратились на семена премиум-качества, и это почти не сказалось на урожае! Запасы овощей пополнены!')
                                self.zapasy_ovoschey["Кабачки"] += kabachki_kupit * 5
                                print(f'Запасы овощей: {self.zapasy_ovoschey}')
                                Fermer.gryadki(self)
                            else:
                                print('Погода была хорошей! Запасы овощей пополнены!')
                                self.zapasy_ovoschey["Кабачки"] += kabachki_kupit * 10
                                print(f'Запасы овощей: {self.zapasy_ovoschey}')
                                Fermer.gryadki(self)

                    else:
                        kabachki_kupit = int(input(f'Сколько пачек семян вы хотите приобрести? Введите целое число или 0 для возврата.'))
                        if kabachki_kupit == 0:
                            print('Вы не купили семена кабачков и не сможете пожарить себе кабачки! Но ваш баланс не изменился')
                            print(f'Ваш баланс: {self.start_money}')
                            Fermer.gryadki(self)
                        else:
                            self.start_money -= kabachki_kupit * 100
                            print(f'У вас осталось {self.start_money} денег.')
                            pogoda = randint (0, 1)

                            if pogoda == 0:
                                print('Погода была плохой, и ваши кабачки сгнили...')
                                Fermer.gryadki(self)
                            else:
                                print('Погода была хорошей! Но семена дешевые, и урожайность маленькая. Но запасы овощей пополнены!')
                                self.ogorod -= 1
                                self.zapasy_ovoschey["Кабачки"] += kabachki_kupit * 3
                                print(f'Запасы овощей: {self.zapasy_ovoschey}')
                                Fermer.gryadki(self)


    def zhivnost(self):
        zhivotnie = input('Хотите ли вы купить животных? Да / Нет')
        if zhivotnie == "Нет" or zhivotnie == "нет":
                print('Вы решили не покупать животных! Но ваш баланс не изменился')
                print(f'Ваш баланс: {self.start_money}')
                

        elif zhivotnie == 'Да' or zhivotnie == 'да':
            
            vybor = int(input(f'У вас {self.start_money} денег. Размер вашего загона: {self.zagon}, поэтому вы можете купить только {self.zagon} животных.\nЧто вы хотите приобрести?\nКорова - 1\nСвинья - 2\nВведите целое число или 0 для возврата.'))
            

            if vybor == 0:
                print('Вы решили не покупать животных! Но ваш баланс не изменился')
                print(f'Ваш баланс: {self.start_money}')
                
            
            elif vybor == 1:
                if self.zagon <= 0:
                    print('Место в загоне закончилось!')
                else:
                    korovka = int(input(f'Вы решили купить корову! У вас {self.start_money} денег.\nКорова стоит 10000 денег. Для покупки коровы введите 1 или введите 0 для возврата.'))
                    if korovka == 0:
                        print('Вы не купили корову! Но ваш баланс не изменился')
                        print(f'Ваш баланс: {self.start_money}')
                        Fermer.zhivnost(self)

                    elif korovka == 1:
                        korovka_kupit = int(input(f'Введите 0 для возврата, если передумали покупать корову, и 1, если хотите продолжить покупку.'))
                        if korovka_kupit == 0:
                            print('Вы не купили корову! Но ваш баланс не изменился.')
                            print(f'Ваш баланс: {self.start_money}')
                            Fermer.zhivnost(self)

                        else:
                            self.zagon -= 1
                            self.start_money -= korovka_kupit * 10000
                            print(f'У вас осталось {self.start_money} денег.')

                            korova_sex = randint (0, 1)
                            if korova_sex == 0:
                                print('Коровка оказалась бычком! Вы остались без молока, но можете получить мясо!')
                                if self.kharakter == 'empat':
                                    print('Вам слишком жалко убивать животных! Пусть бычок живёт у вас на ферме и дальше...')
                                    Fermer.zhivnost(self)
                                elif self.kharakter == 'zlyuka':
                                    print("Вы получили говядину! Место в загоне освободилось!")
                                    self.zagon += 1
                                    self.zapasy_myasa["Говядина"] += 800
                                    print(f'Запасы мяса, молока, яиц, меда: {self.zapasy_myasa}')
                                    Fermer.zhivnost(self)
                            
                            else:
                                print('Коровка даёт молоко! Вы не сможете получить мясо!')
                                self.zapasy_myasa["Молоко"] += 20
                                print(f'Запасы мяса, молока, яиц, меда: {self.zapasy_myasa}')
                                Fermer.zhivnost(self)

            elif vybor == 2:
                if self.zagon <= 0:
                    print('Место в загоне закончилось!')
                else:
                    svinka = int(input(f'Вы решили купить свинью! У вас {self.start_money} денег.\nСвинья стоит 7000 денег. Для покупки свиньи введите 1 или введите 0 для возврата.'))
                    if svinka == 0:
                        print('Вы не купили свинью! Но ваш баланс не изменился')
                        print(f'Ваш баланс: {self.start_money}')
                        Fermer.zhivnost(self)

                    elif svinka == 1:
                        svinka_kupit = int(input(f'Введите 0 для возврата, если передумали покупать свинью, и 1, если хотите продолжить покупку.'))
                        if svinka_kupit == 0:
                            print('Вы не купили свинью! Но ваш баланс не изменился.')
                            print(f'Ваш баланс: {self.start_money}')
                            Fermer.zhivnost(self)

                        else:
                            self.zagon -= 1
                            self.start_money -= svinka_kupit * 7000
                            print(f'У вас осталось {self.start_money} денег.')

                            
                            if self.kharakter == 'empat':
                                print('Вам слишком жалко убивать животных! Пусть свинка живёт у вас на ферме и дальше...')
                                Fermer.zhivnost(self)
                            elif self.kharakter == 'zlyuka':
                                print("Вы получили свинину! Место в загоне освободилось!")
                                self.zagon += 1
                                self.zapasy_myasa["Свинина"] += 70
                                print(f'Запасы мяса, молока, яиц, меда: {self.zapasy_myasa}')
                                Fermer.zhivnost(self)


                            
    def ptitsa(self):
        ptitsa = input('Хотите ли вы купить птиц? Да / Нет')
        if ptitsa == "Нет" or ptitsa == "нет":
                print('Вы решили не покупать птиц! Но ваш баланс не изменился')
                print(f'Ваш баланс: {self.start_money}')
                

        elif ptitsa == 'Да' or ptitsa == 'да':
            
            vybor = int(input(f'У вас {self.start_money} денег. Размер вашего курятника: {self.kuryatnik}, поэтому вы можете купить только {self.kuryatnik} птиц.\nЧто вы хотите приобрести?\nКурица - 1\nИндейка - 2\nВведите целое число или 0 для возврата.'))
            

            if vybor == 0:
                print('Вы решили не покупать птиц! Но ваш баланс не изменился')
                print(f'Ваш баланс: {self.start_money}')
                
            
            elif vybor == 1:
                if self.kuryatnik <= 0:
                    print('Место в курятнике закончилось!')
                else:
                    kuritsa = int(input(f'Вы решили купить курицу! У вас {self.start_money} денег.\nКурица стоит 2000 денег. Для покупки курицы введите 1 или введите 0 для возврата.'))
                    if kuritsa == 0:
                        print('Вы не купили курицу! Но ваш баланс не изменился')
                        print(f'Ваш баланс: {self.start_money}')
                        Fermer.ptitsa(self)

                    elif kuritsa == 1:
                        kuritsa_kupit = int(input(f'Введите 0 для возврата, если передумали покупать курицу, и 1, если хотите продолжить покупку.'))
                        if kuritsa_kupit == 0:
                            print('Вы не купили курицу! Но ваш баланс не изменился.')
                            print(f'Ваш баланс: {self.start_money}')
                            Fermer.ptitsa(self)

                        else:
                            self.kuryatnik -= 1
                            self.start_money -= kuritsa_kupit * 2000
                            print(f'У вас осталось {self.start_money} денег.')

                            kuritsa_sex = randint (0, 1)
                            if kuritsa_sex == 0:
                                print('Курица оказалась петушком! Вы остались без яиц, но можете получить мясо!')
                                if self.kharakter == 'empat':
                                    print('Вам слишком жалко убивать животных! Пусть петушок живёт у вас на ферме и дальше...')
                                    Fermer.ptitsa(self)
                                elif self.kharakter == 'zlyuka':
                                    print("Вы получили куриное мясо! Место в курятнике освободилось!")
                                    self.kuryatnik += 1
                                    self.zapasy_myasa["Курятина"] += 10
                                    print(f'Запасы мяса, молока, яиц, меда: {self.zapasy_myasa}')
                                    Fermer.ptitsa(self)
                            
                            else:
                                print('Курица несет яйца! Вы не сможете получить мясо!')
                                self.zapasy_myasa["Яйца"] += 10
                                print(f'Запасы мяса, молока, яиц, меда: {self.zapasy_myasa}')
                                Fermer.ptitsa(self)

            elif vybor == 2:
                if self.kuryatnik <= 0:
                    print('Место в курятнике закончилось!')
                else:
                    indeyka = int(input(f'Вы решили купить индейку! У вас {self.start_money} денег.\nИндейка стоит 4000 денег. Для покупки индейки введите 1 или введите 0 для возврата.'))
                    if indeyka == 0:
                        print('Вы не купили индейку! Но ваш баланс не изменился')
                        print(f'Ваш баланс: {self.start_money}')
                        Fermer.ptitsa(self)

                    elif indeyka == 1:
                        indeyka_kupit = int(input(f'Введите 0 для возврата, если передумали покупать индейку, и 1, если хотите продолжить покупку.'))
                        if indeyka_kupit == 0:
                            print('Вы не купили индейку! Но ваш баланс не изменился.')
                            print(f'Ваш баланс: {self.start_money}')
                            Fermer.ptitsa(self)

                        else:
                            self.kuryatnik -= 1
                            self.start_money -= indeyka_kupit * 7000
                            print(f'У вас осталось {self.start_money} денег.')

                            
                            if self.kharakter == 'empat':
                                print('Вам слишком жалко убивать животных! Пусть индейка живёт у вас на ферме и дальше...')
                                Fermer.ptitsa(self)
                            elif self.kharakter == 'zlyuka':
                                print("Вы получили мясо индейки! Место в курятнике освободилось!")
                                self.kuryatnik += 1
                                self.zapasy_myasa["Индейка"] += 8
                                print(f'Запасы мяса, молока, яиц, меда: {self.zapasy_myasa}')
                                Fermer.ptitsa(self)


    def med(self):
        pchely = input('Хотите ли вы купить и разводить пчёл? Да / нет')
        #господи, это на самом деле моя мечта... я так хочу разводить пчёл, они такие умные, и у них матриархат! а еще они общаются танцами!!!
        
        if pchely == 'Да' or pchely == 'да':
            if self.paseka <= 0:
                print('У вас нет места для пасеки!')

            else:    
                pchelki = int(input(f'Пчелиная семья стоит 10000. У вас {self.start_money} денег.\nРазмер вашей пасеки: {self.paseka}, поэтому вы можете купить только {self.paseka} ульев.\n Сколько ульев вы хотите приобрести? Введите целое число или 0 для возврата.'))
                
                if pchelki == 0:
                    print('Вы не купили пчёл и остались без мёда! Но ваш баланс не изменился')
                    print(f'Ваш баланс: {self.start_money}')
                    
                else:
                    if pchelki > self.paseka:
                        print('Вы не можете купить столько ульев! Вернитесь в начало и попробуйте заново!')
                        Fermer.med(self)
                    else:
                        self.start_money -= pchelki * 10000
                        print(f'У вас осталось {self.start_money} денег.')
                        self.paseka -= 1
                        print('У вас мёд! Запасы мяса, яиц и мёда пополнены!')
                    
                        self.zapasy_myasa["Мёд"] += pchelki * 40
                        print(f'Запасы мяса, яиц и мёда: {self.zapasy_myasa}')
                    
                            
        elif pchely == "Нет" or pchely == "нет":
                print('Вы не купили пчёл и остались без мёда! Но ваш баланс не изменился')
                print(f'Ваш баланс: {self.start_money}')


    def rynok(self):
        print('Вы пришли на рынок! Вы можете продать свои запасы овощей, мяса, яиц и мёда!\n')
        print(f'Запасы овощей: {self.zapasy_ovoschey}\n')
        print(f'Запасы мяса, яиц и мёда: {self.zapasy_myasa}')

        prodazha = int(input("Что вы хотите продать? Овощи - 1\n Мясо, молоко, мёд - 2. Введите 0 для того, чтобы уйти с рынка."))
        
        if prodazha == 0:
            print('Вы ушли с рынка и ничего не продали. Ваш баланс не изменился!')
            print(f'Текущий баланс: {self.start_money}')
        
        elif prodazha == 1:
            print(f'Вы можете продать: {list(self.zapasy_ovoschey.keys())}')
            ovoschi = int(input('Что вы хотите продать? Введите число по порядку.')) - 1
            print(f'Вы хотите продать {list(self.zapasy_ovoschey.keys())[ovoschi]}')

            if list(self.zapasy_ovoschey.keys())[ovoschi] == 'Картофель':
                um = self.um 
                if um == 'neum':
                    print('Кажется, вас обманули на рынке... Вы продали картофель очень дешево!')
                    kg = self.zapasy_ovoschey.get(list(self.zapasy_ovoschey.keys())[ovoschi])
                    vyruchka = kg * 20
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_ovoschey[list(self.zapasy_ovoschey.keys())[ovoschi]] = 0
                    Fermer.rynok(self)

                if um == 'um':
                    print('Вы продали картофель очень выгодно!')
                    kg = self.zapasy_ovoschey.get(list(self.zapasy_ovoschey.keys())[ovoschi])
                    vyruchka = kg * 100
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_ovoschey[list(self.zapasy_ovoschey.keys())[ovoschi]] = 0
                    Fermer.rynok(self)
                    

            if list(self.zapasy_ovoschey.keys())[ovoschi] == 'Огурцы' or list(self.zapasy_ovoschey.keys())[ovoschi] == 'Помидоры':
                um = self.um 
                if um == 'neum':
                    print('Кажется, вас обманули на рынке... Вы продали свои овощи очень дешево!')
                    kg = self.zapasy_ovoschey.get(list(self.zapasy_ovoschey.keys())[ovoschi])
                    vyruchka = kg * 3
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_ovoschey[list(self.zapasy_ovoschey.keys())[ovoschi]] = 0
                    Fermer.rynok(self) 

                if um == 'um':
                    print('Вы продали свои овощи очень выгодно!')
                    kg = self.zapasy_ovoschey.get(list(self.zapasy_ovoschey.keys())[ovoschi])
                    vyruchka = kg * 10 
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_ovoschey[list(self.zapasy_ovoschey.keys())[ovoschi]] = 0
                    Fermer.rynok(self)

            elif list(self.zapasy_ovoschey.keys())[ovoschi] == 'Перец':
                um = self.um 
                if um == 'neum':
                    print('Кажется, вас обманули на рынке... Вы продали свои овощи очень дешево!')
                    kg = self.zapasy_ovoschey.get(list(self.zapasy_ovoschey.keys())[ovoschi])
                    vyruchka = kg * 5
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_ovoschey[list(self.zapasy_ovoschey.keys())[ovoschi]] = 0
                    Fermer.rynok(self)

                if um == 'um':
                    print('Вы продали свои овощи очень выгодно!')
                    kg = self.zapasy_ovoschey.get(list(self.zapasy_ovoschey.keys())[ovoschi])
                    vyruchka = kg * 25
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_ovoschey[list(self.zapasy_ovoschey.keys())[ovoschi]] = 0
                    Fermer.rynok(self)

            elif list(self.zapasy_ovoschey.keys())[ovoschi] == 'Кабачки':
                um = self.um 
                if um == 'neum':
                    print('Кажется, вас обманули на рынке... Вы продали свои овощи очень дешево!')
                    kg = self.zapasy_ovoschey.get(list(self.zapasy_ovoschey.keys())[ovoschi])
                    vyruchka = kg * 15
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_ovoschey[list(self.zapasy_ovoschey.keys())[ovoschi]] = 0
                    Fermer.rynok(self)

                if um == 'um':
                    print('Вы продали свои овощи очень выгодно!')
                    kg = self.zapasy_ovoschey.get(list(self.zapasy_ovoschey.keys())[ovoschi])
                    vyruchka = kg * 125
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_ovoschey[list(self.zapasy_ovoschey.keys())[ovoschi]] = 0
                    Fermer.rynok(self)

           
        elif prodazha == 2:
            print(f'Вы можете продать: {list(self.zapasy_myasa.keys())}')
            myasko = int(input('Что вы хотите продать? Введите число по порядку.')) - 1
            print(f'Вы хотите продать {list(self.zapasy_myasa.keys())[myasko]}')

            if list(self.zapasy_myasa.keys())[myasko] == 'Свинина':
                um = self.um 

                if um == 'neum':
                    print('Кажется, вас обманули на рынке... Вы продали свинину очень дешево!')
                    kg = self.zapasy_myasa.get(list(self.zapasy_myasa.keys())[myasko])
                    vyruchka = kg * 15
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_myasa[list(self.zapasy_myasa.keys())[myasko]] = 0
                    Fermer.rynok(self)

                if um == 'um':
                    print('Вы продали свинину очень выгодно!')
                    kg = self.zapasy_myasa.get(list(self.zapasy_myasa.keys())[myasko])
                    vyruchka = kg * 50
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_myasa[list(self.zapasy_myasa.keys())[myasko]] = 0
                    Fermer.rynok(self)

            elif list(self.zapasy_myasa.keys())[myasko] == 'Говядина':
                um = self.um 
                if um == 'neum':
                    print('Кажется, вас обманули на рынке... Вы продали говядину очень дешево!')
                    kg = self.zapasy_myasa.get(list(self.zapasy_myasa.keys())[myasko])
                    vyruchka = kg * 20
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_myasa[list(self.zapasy_myasa.keys())[myasko]] = 0
                    Fermer.rynok(self)

                if um == 'um':
                    print('Вы продали говядину очень выгодно!')
                    kg = self.zapasy_myasa.get(list(self.zapasy_myasa.keys())[myasko])
                    vyruchka = kg * 150
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_myasa[list(self.zapasy_myasa.keys())[myasko]] = 0
                    Fermer.rynok(self)

            elif list(self.zapasy_myasa.keys())[myasko] == 'Курятина':
                um = self.um 
                if um == 'neum':
                    print('Кажется, вас обманули на рынке... Вы продали курятину очень дешево!')
                    kg = self.zapasy_myasa.get(list(self.zapasy_myasa.keys())[myasko])
                    vyruchka = kg * 10
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_myasa[list(self.zapasy_myasa.keys())[myasko]] = 0
                    Fermer.rynok(self)

                if um == 'um':
                    print('Вы продали курятину очень выгодно!')
                    kg = self.zapasy_myasa.get(list(self.zapasy_myasa.keys())[myasko])
                    vyruchka = kg * 70
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_myasa[list(self.zapasy_myasa.keys())[myasko]] = 0
                    Fermer.rynok(self)

            elif list(self.zapasy_myasa.keys())[myasko] == 'Индейка':
                um = self.um 
                if um == 'neum':
                    print('Кажется, вас обманули на рынке... Вы продали мясо индейки очень дешево!')
                    kg = self.zapasy_myasa.get(list(self.zapasy_myasa.keys())[myasko])
                    vyruchka = kg * 50
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_myasa[list(self.zapasy_myasa.keys())[myasko]] = 0
                    Fermer.rynok(self)

                if um == 'um':
                    print('Вы продали мячо индейки очень выгодно!')
                    kg = self.zapasy_myasa.get(list(self.zapasy_myasa.keys())[myasko])
                    vyruchka = kg * 200
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_myasa[list(self.zapasy_myasa.keys())[myasko]] = 0
                    Fermer.rynok(self)

            elif list(self.zapasy_myasa.keys())[myasko] == 'Молоко':
                um = self.um 
                if um == 'neum':
                    print('Кажется, вас обманули на рынке... Вы продали молоко очень дешево!')
                    kg = self.zapasy_myasa.get(list(self.zapasy_myasa.keys())[myasko])
                    vyruchka = kg * 15
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_myasa[list(self.zapasy_myasa.keys())[myasko]] = 0
                    Fermer.rynok(self)

                if um == 'um':
                    print('Вы продали молоко очень выгодно!')
                    kg = self.zapasy_myasa.get(list(self.zapasy_myasa.keys())[myasko])
                    vyruchka = kg * 100
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_myasa[list(self.zapasy_myasa.keys())[myasko]] = 0
                    Fermer.rynok(self)

            elif list(self.zapasy_myasa.keys())[myasko] == 'Мёд':
                um = self.um 
                if um == 'neum':
                    print('Кажется, вас обманули на рынке... Вы продали мёд дешево!')
                    kg = self.zapasy_myasa.get(list(self.zapasy_myasa.keys())[myasko])
                    vyruchka = kg * 10
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_myasa[list(self.zapasy_myasa.keys())[myasko]] = 0
                    Fermer.rynok(self)

                if um == 'um':
                    print('Вы продали мёд очень выгодно!')
                    kg = self.zapasy_myasa.get(list(self.zapasy_myasa.keys())[myasko])
                    vyruchka = kg * 150
                    self.start_money += vyruchka
                    print(f'Текущий баланс: {self.start_money}')
                    self.zapasy_myasa[list(self.zapasy_myasa.keys())[myasko]] = 0
                    Fermer.rynok(self)

# %%
lexa = Fermer()
# Out:
# Вам предстоит выбрать характеристики вашей фермы. Будьте внимательны при настройках.
# Всего 10 очков для обустройства фермы. Чем больше очков вы потратите на дом, огород или курятник, тем меньше у вас останется места для загона или картофельного поля.
# Соответсвенно, получится меньше вырастить коров или картофеля
# Настройки фермы:
# Жилплощадь - обязательна
# Картофельное поле - необязательно
# Огород - обязательно
# Загон - обязательно
# Курятник - необязательно
# Пасека - необязательно.
# Пожалуйста, придерживайтесь рамок лимита строительства. Автор игры хлебушек, который мог забыть прописать код ошибки, и игра в конечном итоге сломается. Спасибо!
#
#
# Настройка жилплощади (обязательное значение)
# Ваша жилплощать: 1
# Очки для строительства, которые у вас остались: 9
# Настройка картофельного поля (необязательное значение)
# Ваше картофельное поле: 2
# Очки для строительства, которые у вас остались: 7
# Настройка огорода (обязательное значение)
# Ваш огород: 2
# ...

# %%
lexa.char()
# Out:
# Добро пожаловать, Лёха!

# %%
lexa.skrytiy_stat_1()
# Out:
# Пройдите небольшой тест, чтобы определить скрытый стат вашего фермера!
#
# В тесте будет 6 вопросов. Отвечайте честно!
#
# Вопрос 1.
#
# Вопрос 2.
#
# Вопрос 3.
#
# Вопрос 4.
#
# Вопрос 5.
#
# Вопрос 6.
#
# Спасибо! Скрытый стат вашего персонажа определен!

# %%
lexa.skrytiy_stat_2()
# Out:
# Пройдите небольшой тест, чтобы определить скрытый стат вашего фермера!
#
# В тесте будет 6 вопросов. Отвечайте честно!
#
# Вопрос 1.
#
# Вопрос 2.
#
# Вопрос 3.
#
# Вопрос 4.
#
# Вопрос 5.
#
# Вопрос 6.
#
# Спасибо! Скрытый стат вашего персонажа определен!

# %%
lexa.kartofel()
# Out:
# У вас осталось 49700 денег.
# У вас выросла картошка! Запасы овощей пополнены!
# Запасы овощей: {'Огурцы': 0, 'Картофель': 10, 'Помидоры': 0, 'Перец': 0, 'Кабачки': 0}

# %%
lexa.gryadki()
# Out:
# У вас осталось 49200 денег.
# Погода была хорошей! Но семена дешевые, и урожайность маленькая. Но запасы овощей пополнены!
# Запасы овощей: {'Огурцы': 0, 'Картофель': 10, 'Помидоры': 0, 'Перец': 0, 'Кабачки': 15}
# У вас осталось 48750 денег.
# Погода была хорошей! Запасы овощей пополнены!
# Запасы овощей: {'Огурцы': 30, 'Картофель': 10, 'Помидоры': 0, 'Перец': 0, 'Кабачки': 15}
# Место на грядках закончилось!

# %%
lexa.zhivnost()
# Out:
# У вас осталось 38750 денег.
# Коровка оказалась бычком! Вы остались без молока, но можете получить мясо!
# Вы получили говядину! Место в загоне освободилось!
# Запасы мяса, молока, яиц, меда: {'Свинина': 0, 'Говядина': 800, 'Курятина': 0, 'Индейка': 0, 'Молоко': 0, 'Яйца': 0, 'Мёд': 0}
# У вас осталось 28750 денег.
# Коровка даёт молоко! Вы не сможете получить мясо!
# Запасы мяса, молока, яиц, меда: {'Свинина': 0, 'Говядина': 800, 'Курятина': 0, 'Индейка': 0, 'Молоко': 20, 'Яйца': 0, 'Мёд': 0}
# У вас осталось 18750 денег.
# Коровка даёт молоко! Вы не сможете получить мясо!
# Запасы мяса, молока, яиц, меда: {'Свинина': 0, 'Говядина': 800, 'Курятина': 0, 'Индейка': 0, 'Молоко': 40, 'Яйца': 0, 'Мёд': 0}
# Место в загоне закончилось!

# %%
lexa.ptitsa()
# Out:
# У вас осталось 16750 денег.
# Курица оказалась петушком! Вы остались без яиц, но можете получить мясо!
# Вы получили куриное мясо! Место в курятнике освободилось!
# Запасы мяса, молока, яиц, меда: {'Свинина': 0, 'Говядина': 800, 'Курятина': 10, 'Индейка': 0, 'Молоко': 40, 'Яйца': 0, 'Мёд': 0}
# У вас осталось 14750 денег.
# Курица несет яйца! Вы не сможете получить мясо!
# Запасы мяса, молока, яиц, меда: {'Свинина': 0, 'Говядина': 800, 'Курятина': 10, 'Индейка': 0, 'Молоко': 40, 'Яйца': 10, 'Мёд': 0}
# Место в курятнике закончилось!

# %%
lexa.med()
# Out:
# У вас осталось 4750 денег.
# У вас мёд! Запасы мяса, яиц и мёда пополнены!
# Запасы мяса, яиц и мёда: {'Свинина': 0, 'Говядина': 800, 'Курятина': 10, 'Индейка': 0, 'Молоко': 40, 'Яйца': 10, 'Мёд': 40}

# %%
lexa.rynok()
# Out:
# Вы пришли на рынок! Вы можете продать свои запасы овощей, мяса, яиц и мёда!
#
# Запасы овощей: {'Огурцы': 30, 'Картофель': 10, 'Помидоры': 0, 'Перец': 0, 'Кабачки': 15}
#
# Запасы мяса, яиц и мёда: {'Свинина': 0, 'Говядина': 800, 'Курятина': 10, 'Индейка': 0, 'Молоко': 40, 'Яйца': 10, 'Мёд': 40}
# Вы можете продать: ['Огурцы', 'Картофель', 'Помидоры', 'Перец', 'Кабачки']
# Вы хотите продать Картофель
# Вы продали картофель очень выгодно!
# Текущий баланс: 5750
# Вы пришли на рынок! Вы можете продать свои запасы овощей, мяса, яиц и мёда!
#
# Запасы овощей: {'Огурцы': 30, 'Картофель': 0, 'Помидоры': 0, 'Перец': 0, 'Кабачки': 15}
#
# Запасы мяса, яиц и мёда: {'Свинина': 0, 'Говядина': 800, 'Курятина': 10, 'Индейка': 0, 'Молоко': 40, 'Яйца': 10, 'Мёд': 40}
# Вы можете продать: ['Свинина', 'Говядина', 'Курятина', 'Индейка', 'Молоко', 'Яйца', 'Мёд']
# Вы хотите продать Говядина
# Вы продали говядину очень выгодно!
# Текущий баланс: 125750
# ...
